# %%
import numpy as np

# %%
x = np.linspace(0, 2, 10)
y = x**2
print(x)
# Out:
# [0.         0.22222222 0.44444444 0.66666667 0.88888889 1.11111111
#  1.33333333 1.55555556 1.77777778 2.        ]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, y)

# %%
plt.show()

# %%
plt.figure(figsize=())
plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-6e557c63a330> in <module>
# ----> 1 plt.figure(figsize=())
#       2 plt.plot(x, y)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#     543                                         frameon=frameon,
#     544                                         FigureClass=FigureClass,
# --> 545                                         **kwargs)
#     546
#     547         if figLabel:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in new_figure_manager(cls, num, *args, **kwargs)
#    3249         from matplotlib.figure import Figure
#    3250         fig_cls = kwargs.pop('FigureClass', Figure)
# -> 3251         fig = fig_cls(*args, **kwargs)
# ...

# %%
plt.figure(figsize=(12, 8))
plt.plot(x, y)
plt.plot(x, x**3)
plt.title('Hello')
plt.xlabel('axe x')
plt.ylabel('axe y')
# Out:
# Text(0, 0.5, 'axe y')

# %%
plt.plot(x, y)
